# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Importing Insight_002 Dataset

# %%
df = pd.read_excel('insight_002.xlsx')
df.head()
# Out:
#                              Post ID  \
# 0                                NaN
# 1  1277547548992987_1741796732568064
# 2  1277547548992987_1731769263570811
# 3  1277547548992987_1731343926946678
# 4  1277547548992987_1727479250666479
#
#                                         Post Message   Type  Countries  \
# 0                                                NaN    NaN        NaN
# 1  Congratulations to the winners of the first on...  Photo        NaN
# 2  May your Eid celebrations be as charming as th...  Video        NaN
# 3  Wishing everyone a very happy Eid al-Fitr. As ...  Photo        NaN
# 4                        What's trending this eid? 🤔  Photo        NaN
#
#    Languages              Posted Audience Targeting  \
# 0        NaN                 NaT                NaN
# 1        NaN 2018-06-22 07:58:04
# 2        NaN 2018-06-15 13:43:23
# 3        NaN 2018-06-15 06:57:45
# 4        NaN 2018-06-12 11:33:50
#
#                            Lifetime Post Total Reach  \
# ...

# %% [markdown]
# Removing Unnecessary Rows

# %%
df = df.drop(df.index[0])

# %%
df = df[df.columns.drop(list(df.filter(regex='Paid')))]
df.head()
# Out:
#                              Post ID  \
# 1  1277547548992987_1741796732568064
# 2  1277547548992987_1731769263570811
# 3  1277547548992987_1731343926946678
# 4  1277547548992987_1727479250666479
# 5  1277547548992987_1725257400888664
#
#                                         Post Message   Type  Countries  \
# 1  Congratulations to the winners of the first on...  Photo        NaN
# 2  May your Eid celebrations be as charming as th...  Video        NaN
# 3  Wishing everyone a very happy Eid al-Fitr. As ...  Photo        NaN
# 4                        What's trending this eid? 🤔  Photo        NaN
# 5  Hey IDCians! We are here with our first online...  Photo        NaN
#
#    Languages              Posted Audience Targeting Lifetime Post Total Reach  \
# 1        NaN 2018-06-22 07:58:04                                            2
# 2        NaN 2018-06-15 13:43:23                                         1556
# ...

# %% [markdown]
# Dropping Columns that show no significant impact

# %%
df = df.drop(['Post ID', 'Post Message', 'Countries',  'Languages', 'Posted', 'Audience Targeting'], axis=1)

# %%
df.head()
# Out:
#     Type Lifetime Post Total Reach Lifetime Post organic reach  \
# 1  Photo                         2                           2
# 2  Video                      1556                        1556
# 3  Photo                         2                           2
# 4  Photo                         1                           1
# 5  Photo                         2                           2
#
#   Lifetime Post Total Impressions Lifetime Post Organic Impressions  \
# 1                               2                                 2
# 2                            3125                              3125
# 3                               2                                 2
# 4                               1                                 1
# 5                               2                                 2
#
#   Lifetime Engaged Users  \
# 1                      0
# 2                    148
# 3                      0
# 4                      0
# 5                      0
#
# ...

# %%
df1 = df[df.columns.drop(list(df.filter(regex='Organic views')))]
df1.head()
# Out:
#     Type Lifetime Post Total Reach Lifetime Post organic reach  \
# 1  Photo                         2                           2
# 2  Video                      1556                        1556
# 3  Photo                         2                           2
# 4  Photo                         1                           1
# 5  Photo                         2                           2
#
#   Lifetime Post Total Impressions Lifetime Post Organic Impressions  \
# 1                               2                                 2
# 2                            3125                              3125
# 3                               2                                 2
# 4                               1                                 1
# 5                               2                                 2
#
#   Lifetime Engaged Users  \
# 1                      0
# 2                    148
# 3                      0
# 4                      0
# 5                      0
#
# ...

# %%
df2 = df1[df1.columns.drop(list(df1.filter(regex='Matched Audience')))]
df2.head()
# Out:
#     Type Lifetime Post Total Reach Lifetime Post organic reach  \
# 1  Photo                         2                           2
# 2  Video                      1556                        1556
# 3  Photo                         2                           2
# 4  Photo                         1                           1
# 5  Photo                         2                           2
#
#   Lifetime Post Total Impressions Lifetime Post Organic Impressions  \
# 1                               2                                 2
# 2                            3125                              3125
# 3                               2                                 2
# 4                               1                                 1
# 5                               2                                 2
#
#   Lifetime Engaged Users Lifetime Negative Feedback from Users  \
# 1                      0                                     0
# ...

# %%
df3 = df2[df2.columns.drop(list(df2.filter(regex='Feedback')))]
df3.head()
# Out:
#     Type Lifetime Post Total Reach Lifetime Post organic reach  \
# 1  Photo                         2                           2
# 2  Video                      1556                        1556
# 3  Photo                         2                           2
# 4  Photo                         1                           1
# 5  Photo                         2                           2
#
#   Lifetime Post Total Impressions Lifetime Post Organic Impressions  \
# 1                               2                                 2
# 2                            3125                              3125
# 3                               2                                 2
# 4                               1                                 1
# 5                               2                                 2
#
#   Lifetime Engaged Users  \
# 1                      0
# 2                    148
# 3                      0
# 4                      0
# 5                      0
#
# ...

# %%
df4 = df3[df3.columns.drop(list(df3.filter(regex='Video View')))]
df4.head()
# Out:
#     Type Lifetime Post Total Reach Lifetime Post organic reach  \
# 1  Photo                         2                           2
# 2  Video                      1556                        1556
# 3  Photo                         2                           2
# 4  Photo                         1                           1
# 5  Photo                         2                           2
#
#   Lifetime Post Total Impressions Lifetime Post Organic Impressions  \
# 1                               2                                 2
# 2                            3125                              3125
# 3                               2                                 2
# 4                               1                                 1
# 5                               2                                 2
#
#   Lifetime Engaged Users  \
# 1                      0
# 2                    148
# 3                      0
# 4                      0
# 5                      0
#
# ...

# %% [markdown]
# Renaming Coulumns for Better Understandings

# %%
df4.rename(columns = {'Lifetime People who have liked your Page and engaged with your post':'Liketime Liked & Engaged', 
                           'Lifetime Average time video viewed':'Lifetime Average Video Length', 
                              'Lifetime Post reach by people who like your Page':'Lifetime Post Reach by Liked People',
                          'Lifetime Post Impressions by people who have liked your Page': 'Lifetime Post Impression by Liked People',
                          }, inplace = True)
# Out:
# C:\Anaconda\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df4
# Out:
#             Type Lifetime Post Total Reach Lifetime Post organic reach  \
# 1          Photo                         2                           2
# 2          Video                      1556                        1556
# 3          Photo                         2                           2
# 4          Photo                         1                           1
# 5          Photo                         2                           2
# ..           ...                       ...                         ...
# 287       Status                       634                         634
# 288  SharedVideo                       654                         654
# 289  SharedVideo                       488                         488
# 290        Photo                       969                         969
# 291        Photo                      2149                        2149
#
#     Lifetime Post Total Impressions Lifetime Post Organic Impressions  \
# ...

# %%
df = df4

# %%
df = df.drop(['Lifetime Post organic reach', 'Lifetime Post Organic Impressions'], axis = 1)

# %%
df
# Out:
#             Type Lifetime Post Total Reach Lifetime Post Total Impressions  \
# 1          Photo                         2                               2
# 2          Video                      1556                            3125
# 3          Photo                         2                               2
# 4          Photo                         1                               1
# 5          Photo                         2                               2
# ..           ...                       ...                             ...
# 287       Status                       634                             726
# 288  SharedVideo                       654                             758
# 289  SharedVideo                       488                             563
# 290        Photo                       969                            1148
# 291        Photo                      2149                            2611
#
# ...

# %%
multimedia = df.drop(['Lifetime Engaged Users', 'Liketime Liked & Engaged', 'Lifetime Average Video Length', 'Lifetime Video length'], axis = 1)

# %%
multimedia
# Out:
#             Type Lifetime Post Total Reach Lifetime Post Total Impressions  \
# 1          Photo                         2                               2
# 2          Video                      1556                            3125
# 3          Photo                         2                               2
# 4          Photo                         1                               1
# 5          Photo                         2                               2
# ..           ...                       ...                             ...
# 287       Status                       634                             726
# 288  SharedVideo                       654                             758
# 289  SharedVideo                       488                             563
# 290        Photo                       969                            1148
# 291        Photo                      2149                            2611
#
#     Lifetime Post Impression by Liked People  \
# ...

# %% [markdown]
# To have a better understanding of each multimedia types impact on the dataset, We will group them by 'Photos', 'Links', 'Video', 'Status', 'ShareVideo' categories

# %%
category = df.groupby("Type")

# %%
photo = category.get_group('Photo')
photo
# Out:
#       Type Lifetime Post Total Reach Lifetime Post Total Impressions  \
# 1    Photo                         2                               2
# 3    Photo                         2                               2
# 4    Photo                         1                               1
# 5    Photo                         2                               2
# 8    Photo                         3                               3
# ..     ...                       ...                             ...
# 284  Photo                      2158                            2445
# 285  Photo                      1324                            1614
# 286  Photo                       762                             901
# 290  Photo                       969                            1148
# 291  Photo                      2149                            2611
#
#     Lifetime Engaged Users Lifetime Post Impression by Liked People  \
# 1                        0                                        2
# ...

# %% [markdown]
# Removing Insignificant Columns

# %%
photo = photo.drop(['Lifetime Post Impression by Liked People', 'Liketime Liked & Engaged', 'Lifetime Average Video Length', 'Lifetime Video length', 'Lifetime Post Reach by Liked People'], axis = 1)

# %%
photo
# Out:
#       Type Lifetime Post Total Reach Lifetime Post Total Impressions  \
# 1    Photo                         2                               2
# 3    Photo                         2                               2
# 4    Photo                         1                               1
# 5    Photo                         2                               2
# 8    Photo                         3                               3
# ..     ...                       ...                             ...
# 284  Photo                      2158                            2445
# 285  Photo                      1324                            1614
# 286  Photo                       762                             901
# 290  Photo                       969                            1148
# 291  Photo                      2149                            2611
#
#     Lifetime Engaged Users
# 1                        0
# 3                        0
# 4                        0
# ...

# %% [markdown]
# Renaming Columns for Better Understandings

# %%
photo.rename(columns = {'Lifetime Post Total Reach':'Total Reach by Photo',
                      'Lifetime Post Total Impressions': 'Total Impression by Photo',
                      'Lifetime Engaged Users': 'Total Engaged Users by Photo' }, inplace = True)

# %%
photo
# Out:
#       Type Total Reach by Photo Total Impression by Photo  \
# 1    Photo                    2                         2
# 3    Photo                    2                         2
# 4    Photo                    1                         1
# 5    Photo                    2                         2
# 8    Photo                    3                         3
# ..     ...                  ...                       ...
# 284  Photo                 2158                      2445
# 285  Photo                 1324                      1614
# 286  Photo                  762                       901
# 290  Photo                  969                      1148
# 291  Photo                 2149                      2611
#
#     Total Engaged Users by Photo
# 1                              0
# 3                              0
# 4                              0
# 5                              0
# 8                              0
# ..                           ...
# ...

# %%
photo = pd.DataFrame(photo.sum(), columns=['sum'])
photo
# Out:
#                                                                             sum
# Type                          PhotoPhotoPhotoPhotoPhotoPhotoPhotoPhotoPhotoP...
# Total Reach by Photo                                                     332059
# Total Impression by Photo                                                440995
# Total Engaged Users by Photo                                              27067

# %% [markdown]
# Working with Status Group

# %%
Status = category.get_group('Status')
Status
# Out:
#        Type Lifetime Post Total Reach Lifetime Post Total Impressions  \
# 34   Status                         2                               2
# 38   Status                         2                               2
# 39   Status                         2                               2
# 41   Status                         2                               2
# 44   Status                         0                               0
# 48   Status                         0                               0
# 59   Status                         3                               4
# 99   Status                      2815                            4723
# 113  Status                      7162                           10714
# 114  Status                       540                             736
# 117  Status                      1915                            2508
# 121  Status                      2096                            2328
# ...

# %%
Status = Status.drop(['Lifetime Post Impression by Liked People', 'Liketime Liked & Engaged', 'Lifetime Average Video Length', 'Lifetime Video length', 'Lifetime Post Reach by Liked People'], axis = 1)

# %%
Status
# Out:
#        Type Lifetime Post Total Reach Lifetime Post Total Impressions  \
# 34   Status                         2                               2
# 38   Status                         2                               2
# 39   Status                         2                               2
# 41   Status                         2                               2
# 44   Status                         0                               0
# 48   Status                         0                               0
# 59   Status                         3                               4
# 99   Status                      2815                            4723
# 113  Status                      7162                           10714
# 114  Status                       540                             736
# 117  Status                      1915                            2508
# 121  Status                      2096                            2328
# ...

# %%
Status.rename(columns = {'Lifetime Post Total Reach':'Total Reach by Status',
                      'Lifetime Post Total Impressions': 'Total Impression by Status',
                      'Lifetime Engaged Users': 'Total Engaged Users by Status' }, inplace = True)

# %%
Status
# Out:
#        Type Total Reach by Status Total Impression by Status  \
# 34   Status                     2                          2
# 38   Status                     2                          2
# 39   Status                     2                          2
# 41   Status                     2                          2
# 44   Status                     0                          0
# 48   Status                     0                          0
# 59   Status                     3                          4
# 99   Status                  2815                       4723
# 113  Status                  7162                      10714
# 114  Status                   540                        736
# 117  Status                  1915                       2508
# 121  Status                  2096                       2328
# 123  Status                   988                       1012
# 130  Status                   450                        482
# ...

# %%
Status = pd.DataFrame(Status.sum(), columns=['sum'])
Status
# Out:
#                                                                              sum
# Type                           StatusStatusStatusStatusStatusStatusStatusStat...
# Total Reach by Status                                                      29817
# Total Impression by Status                                                 40089
# Total Engaged Users by Status                                               2523

# %% [markdown]
# Working With Video Group

# %%
Video = category.get_group('Video')
Video
# Out:
#       Type Lifetime Post Total Reach Lifetime Post Total Impressions  \
# 2    Video                      1556                            3125
# 6    Video                      1095                            1992
# 7    Video                      3975                            7985
# 13   Video                      2542                            5672
# 18   Video                      2648                            4264
# 21   Video                      1980                            2986
# 28   Video                      3887                            9231
# 31   Video                      2294                            3715
# 46   Video                      3690                            5421
# 51   Video                      3140                            4761
# 52   Video                      3350                            4751
# 53   Video                      2366                            3501
# 67   Video                      2344                            3943
# ...

# %%
Video = Video.drop(['Lifetime Post Impression by Liked People', 'Liketime Liked & Engaged', 'Lifetime Average Video Length', 'Lifetime Video length', 'Lifetime Post Reach by Liked People'], axis = 1)

# %%
Video.rename(columns = {'Lifetime Post Total Reach':'Total Reach by Video',
                      'Lifetime Post Total Impressions': 'Total Impression by Video',
                      'Lifetime Engaged Users': 'Total Engaged Users by Video' }, inplace = True)

# %%
Video = pd.DataFrame(Video.sum(), columns=['sum'])
Video
# Out:
#                                                                             sum
# Type                          VideoVideoVideoVideoVideoVideoVideoVideoVideoV...
# Total Reach by Video                                                     126972
# Total Impression by Video                                                205324
# Total Engaged Users by Video                                              13853

# %% [markdown]
# Working With Link Data

# %%
Link = category.get_group('Link')
Link
# Out:
#      Type Lifetime Post Total Reach Lifetime Post Total Impressions  \
# 20   Link                      1036                            1483
# 30   Link                         1                               1
# 35   Link                         2                               2
# 42   Link                         2                               2
# 61   Link                         3                               3
# 65   Link                         3                               3
# 80   Link                         2                               2
# 81   Link                         2                               2
# 87   Link                         2                               2
# 88   Link                       373                             524
# 107  Link                      2341                            3267
# 116  Link                      1091                            1268
# 143  Link                       275                             285
# ...

# %%
Link = Link.drop(['Lifetime Post Impression by Liked People', 'Liketime Liked & Engaged', 'Lifetime Average Video Length', 'Lifetime Video length', 'Lifetime Post Reach by Liked People'], axis = 1)

# %%
Link.rename(columns = {'Lifetime Post Total Reach':'Total Reach by Link',
                      'Lifetime Post Total Impressions': 'Total Impression by Link',
                      'Lifetime Engaged Users': 'Total Engaged Users by Link' }, inplace = True)

# %%
Link = pd.DataFrame(Link.sum(), columns=['sum'])
Link
# Out:
#                                                                            sum
# Type                         LinkLinkLinkLinkLinkLinkLinkLinkLinkLinkLinkLi...
# Total Reach by Link                                                      13446
# Total Impression by Link                                                 17050
# Total Engaged Users by Link                                               1120

# %% [markdown]
# Working With Shared Video

# %%
SharedVideo = category.get_group('SharedVideo')
SharedVideo
# Out:
#             Type Lifetime Post Total Reach Lifetime Post Total Impressions  \
# 49   SharedVideo                       338                             379
# 72   SharedVideo                       743                            1011
# 75   SharedVideo                      1185                            1695
# 82   SharedVideo                      1258                            1791
# 125  SharedVideo                       806                             868
# 128  SharedVideo                       964                             996
# 142  SharedVideo                       733                             775
# 182  SharedVideo                       608                             723
# 198  SharedVideo                       645                             789
# 218  SharedVideo                       723                             883
# 249  SharedVideo                       707                             850
# ...

# %%
SharedVideo = SharedVideo.drop(['Lifetime Post Impression by Liked People', 'Liketime Liked & Engaged', 'Lifetime Average Video Length', 'Lifetime Video length', 'Lifetime Post Reach by Liked People'], axis = 1)

# %%
SharedVideo.rename(columns = {'Lifetime Post Total Reach':'Total Reach by SharedVideo',
                      'Lifetime Post Total Impressions': 'Total Impression by SharedVideo',
                      'Lifetime Engaged Users': 'Total Engaged Users by SharedVideo' }, inplace = True)

# %%
SharedVideo = pd.DataFrame(SharedVideo.sum(), columns=['sum'])
SharedVideo
# Out:
#                                                                                   sum
# Type                                SharedVideoSharedVideoSharedVideoSharedVideoSh...
# Total Reach by SharedVideo                                                      15208
# Total Impression by SharedVideo                                                 18720
# Total Engaged Users by SharedVideo                                               1066

# %%
frames = [photo, SharedVideo, Link, Video, Status]
result = pd.concat(frames)
result
# Out:
#                                                                                   sum
# Type                                PhotoPhotoPhotoPhotoPhotoPhotoPhotoPhotoPhotoP...
# Total Reach by Photo                                                           332059
# Total Impression by Photo                                                      440995
# Total Engaged Users by Photo                                                    27067
# Type                                SharedVideoSharedVideoSharedVideoSharedVideoSh...
# Total Reach by SharedVideo                                                      15208
# Total Impression by SharedVideo                                                 18720
# Total Engaged Users by SharedVideo                                               1066
# Type                                LinkLinkLinkLinkLinkLinkLinkLinkLinkLinkLinkLi...
# Total Reach by Link                                                             13446
# ...

# %%
df = result.transpose()
df
# Out:
#                                                   Type Total Reach by Photo  \
# sum  PhotoPhotoPhotoPhotoPhotoPhotoPhotoPhotoPhotoP...               332059
#
#     Total Impression by Photo Total Engaged Users by Photo  \
# sum                    440995                        27067
#
#                                                   Type  \
# sum  SharedVideoSharedVideoSharedVideoSharedVideoSh...
#
#     Total Reach by SharedVideo Total Impression by SharedVideo  \
# sum                      15208                           18720
#
#     Total Engaged Users by SharedVideo  \
# sum                               1066
#
#                                                   Type Total Reach by Link  \
# sum  LinkLinkLinkLinkLinkLinkLinkLinkLinkLinkLinkLi...               13446
#
#     Total Impression by Link Total Engaged Users by Link  \
# sum                    17050                        1120
#
#                                                   Type Total Reach by Video  \
# ...

# %%
df = result[result.columns.drop(list(result.filter(regex='Type')))]
df.head()
# Out:
#                                                                             sum
# Type                          PhotoPhotoPhotoPhotoPhotoPhotoPhotoPhotoPhotoP...
# Total Reach by Photo                                                     332059
# Total Impression by Photo                                                440995
# Total Engaged Users by Photo                                              27067
# Type                          SharedVideoSharedVideoSharedVideoSharedVideoSh...

# %%
df = df.drop(['Type'], axis = 1)

# %%
# Out:
#     Total Reach by Photo Total Impression by Photo  \
# sum               332059                    440995
#
#     Total Engaged Users by Photo Total Reach by SharedVideo  \
# sum                        27067                      15208
#
#     Total Impression by SharedVideo Total Engaged Users by SharedVideo  \
# sum                           18720                               1066
#
#     Total Reach by Link Total Impression by Link Total Engaged Users by Link  \
# sum               13446                    17050                        1120
#
#     Total Reach by Video Total Impression by Video  \
# sum               126972                    205324
#
#     Total Engaged Users by Video Total Reach by Status  \
# sum                        13853                 29817
#
#     Total Impression by Status Total Engaged Users by Status
# sum                      40089                          2523

# %% [markdown]
# A pie Chart to show the impact of each medium on total reach

# %%
reach = [332059,15208,13446,126972,29817]
medium = ["Photo","SharedVideo","Link","Video ","Status"]

plt.axis("equal")
plt.pie(reach,labels=medium, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0.1,0.15,0.4,0.1,0.1])
plt.savefig("Total Reach by Medium.jpg", bbox_inches="tight", pad_inches=1, transparent=True)

# %% [markdown]
# A pie Chart to show the impact of each medium on total Impression

# %%
impression = [440995,18720,17050,205324,40089]
medium = ["Photo","SharedVideo","Link","Video ","Status"]

plt.axis("equal")
plt.pie(impression,labels=medium, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0.1,0.15,0.4,0.1,0.1], counterclock=True, startangle=45)
plt.savefig("Total Impression by Medium.jpg", bbox_inches="tight", pad_inches=1, transparent=True)

# %% [markdown]
# A pie Chart to show the impact of each medium on total Engagement

# %%
Engagement = [27067,1066,1120,13853,2523]
medium = ["Photo","SharedVideo","Link","Video ","Status"]

plt.axis("equal")
plt.pie(Engagement,labels=medium, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0.1,0.4,0.4,0.1,0.1])
plt.savefig("Total Engagement by Medium.jpg", bbox_inches="tight", pad_inches=1, transparent=True)

# %% [markdown]
# We can observe a very interesting trait. Photo dominates in every sector. But the more interesting trait is how much of percentage it dominates. It's always close to 60%, Video is the second most popular feature, having an average 25 to 30 percent dominance. Status comes in third with about 5.5%.
#
# Sharedvideo and Link is actually a joint winner in this case, with almost everytime both having a percentage about 2.5.
